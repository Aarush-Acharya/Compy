# %%
import pandas as pd
a = pd.read_csv("Computer Preference Analysis (Responses) - Form Responses 1 (1).csv")
a
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/3f/6_71ktsd1875x94yx4y7lq5w0000gn/T/ipykernel_77449/2591249431.py in <module>
#       1 import pandas as pd
# ----> 2 a = pd.read_csv("Computer Preference Analysis (Responses) - Form Responses 1 (1).csv")
#       3 a
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Computer Preference Analysis (Responses) - Form Responses 1 (1).csv'

# %%
df = a.drop('Timestamp', axis = 1)
df.rename(columns = {'Field of interest':'Field'}, inplace = True)
df.rename(columns = {'Brand of your laptop that you are using for your use case?':'Brand'}, inplace = True)
df.rename(columns = {'The processor of your laptop that you use for your use case?':'Processor'}, inplace = True)
df.rename(columns = {'The Graphic Card of your laptop that you use for your use case?':'GCard'}, inplace = True)
df.rename(columns = {'The RAM of your laptop that you use for your use case?':'RAM'}, inplace = True)
df.rename(columns = {'The OS of your laptop that you use for your use case?':'OS'}, inplace = True)
df.rename(columns = {'Scale your priority for tech specs you would go for buying a laptop for your usecase(1 being the lowest and 4 being the highest)\n [Processor ]':'Prior_Pross'}, inplace = True)
df.rename(columns = {'Scale your priority for tech specs you would go for buying a laptop for your usecase(1 being the lowest and 4 being the highest)\n [Graphic Card]':'Prior_GC'}, inplace = True)
df.rename(columns = {'Scale your priority for tech specs you would go for buying a laptop for your usecase(1 being the lowest and 4 being the highest)\n [RAM]':'Prior_RAM'}, inplace = True)
df.rename(columns = {'Scale your priority for tech specs you would go for buying a laptop for your usecase(1 being the lowest and 4 being the highest)\n [OS]':'Prior_OS'}, inplace = True)
df['GCard'] = df['GCard'].replace(to_replace='Integrated', value='Integrated/Shared')
df['GCard'] = df['GCard'].replace(to_replace='Discrete', value='Discrete/Dedicated')

df
# Out:
#               Field   Brand Processor               GCard    RAM       OS  \
# 0      Data Science    Dell  Intel I5  Discrete/Dedicated   8 GB  Windows
# 1      Data Science    Dell  Intel I5  Discrete/Dedicated  16 GB  Windows
# 2      Data Science  Lenovo   Ryzen 7   Integrated/Shared  16 GB  Windows
# 3      Data Science    Dell  Intel I5  Discrete/Dedicated   8 GB  Windows
# 4      Data Science    Dell   Ryzen 5   Integrated/Shared   8 GB  Windows
# ..              ...     ...       ...                 ...    ...      ...
# 207    Data Science    Dell  Intel I7   Integrated/Shared  16 GB  Windows
# 208              AI  Lenovo  Intel I5   Integrated/Shared   8 GB  Windows
# 209              AI    Dell  Intel I7   Integrated/Shared  16 GB  Windows
# 210  IOT & Robotics      HP  Intel I5   Integrated/Shared   8 GB  Windows
# 211    Data Science      HP  Intel I7  Discrete/Dedicated  16 GB  Windows
#
#      Prior_Pross  Prior_GC  Prior_RAM  Prior_OS
# 0              2         1          3         4
# 1              2         1          4         3
# 2              3         4          2         3
# 3              3         1          2         4
# 4              3         2          2         4
# ..           ...       ...        ...       ...
# 207            4         1          3         2
# 208            4         3          4         4
# 209            4         1          3         2
# 210            4         2          3         1
# 211            4         3          4         4
#
# [212 rows x 10 columns]

# %%
# Test
df_Data = df.loc[df['Field'] == 'AI']
df_Data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/3f/6_71ktsd1875x94yx4y7lq5w0000gn/T/ipykernel_77449/128052120.py in <module>
#       1 # Test
# ----> 2 df_Data = df.loc[df['Field'] == 'AI']
#       3 df_Data
#
# NameError: name 'df' is not defined

# %%
# Test
df_Data.columns[0]
# Out:
# 'Field'

# %%
# Test ------------------------------------------------------
processor_count = pd.value_counts(df_Data.Processor)
# print(processor_count.idxmax())
# print(processor_count)
# process_max = processor_count.max()
# print(process_max)
#brand_df = brand_count.to_frame(name='Brand')
processor_df = processor_count.to_frame(name='Processor')
df1p = pd.concat([processor_df], axis=1)
df1p
df1p.reset_index(level=0, inplace=True)
df1p
df1p.rename(columns = {'index':'Processor', 'Processor':'Count'}, inplace = True)
df1p
df1p.Count.max()
df2p = df1p[df1p.Count == df1p.Count.max()]
df2p
# print(df2p)
# len(df2p)
# print("The people with Data Science usually use ")
# for i in range(0, len(df2p)):
#   print(df2p.Processor[i], " ")

# print("processor Laptops")
# Out:
#   Processor  Count
# 0  Intel I5     21

# %%
df_count = pd.value_counts(df[df.columns[0]])
feilds_df = df_count.to_frame(name=df.columns[0])
feilds_df
# #RAM_df = RAM_count.to_frame(name='RAM')
df1ff = pd.concat([feilds_df], axis=1)
df1ff
df1ff.reset_index(level=0, inplace=True)
df1ff
df1ff.rename(columns = {'index':df.columns[0], df.columns[0]:'Count'}, inplace = True)
df1ff
# for j in range(0, len(df1ff)):
#   print(df1ff[df1ff.columns[0]][j], " ")
# Out:
#                              Field  Count
# 0                     Data Science     66
# 1                               AI     56
# 2                           Gaming     25
# 3                   Cyber Security     15
# 4                  Cloud Computing     14
# 5                      Block Chain     12
# 6                    Video Editing      9
# 7                   IOT & Robotics      5
# 8                      3D Modeling      2
# 9                 Web Development       1
# 10                           Ui/ux      1
# 11                      General CS      1
# 12                           AR VR      1
# 13              No specialization       1
# 14  Basic coding and casual gaming      1
# 15                            Core      1
# 16                          Devops      1

# %%
# Test 2 ------------------------------------------------------------
ls = []
count = []
for i in range(2, 6):
  processor_count = pd.value_counts(df_Data[df_Data.columns[i]])
  # print(processor_count.idxmax())
  # print(processor_count)
  # process_max = processor_count.max()
  # print(process_max)
  #brand_df = brand_count.to_frame(name='Brand')
  processor_df = processor_count.to_frame(name=df_Data.columns[i])
  #RAM_df = RAM_count.to_frame(name='RAM')
  df1p = pd.concat([processor_df], axis=1)
  df1p
  df1p.reset_index(level=0, inplace=True)
  df1p.rename(columns = {'index':df_Data.columns[i], df_Data.columns[i]:'Count'}, inplace = True)
  df1p
#   df1p.Count.max()
#   df2p = df1p[df1p.Count == df1p.Count.max()]
#   print(df2p)
#   len(df2p)
#   print("The people with Data Science usually use ")
#   for j in range(0, len(df2p)):
#     print(df2p[df2p.columns[0]][j], " ")
#   print(df2p.columns[0]+" laptops \n\n\n")
# print(ls)
# print(count)

# %%
# Main Code

for k in range(0, len(df1ff)):
  print(df1ff[df1ff.columns[0]][k], " ")
  df_Data = df.loc[df['Field'] == df1ff[df1ff.columns[0]][k]]
  ls = []
  count = []
  for i in range(2, 6):
    processor_count = pd.value_counts(df_Data[df_Data.columns[i]])
    processor_df = processor_count.to_frame(name=df_Data.columns[i])
    #RAM_df = RAM_count.to_frame(name='RAM')
    df1p = pd.concat([processor_df], axis=1)
    df1p
    df1p.reset_index(level=0, inplace=True)
    df1p.rename(columns = {'index':df_Data.columns[i], df_Data.columns[i]:'Count'}, inplace = True)
    df1p.Count.max()
    df2p = df1p[df1p.Count == df1p.Count.max()]
    print(df2p)
    len(df2p)
    print("The people with", df1ff[df1ff.columns[0]][k] ,"usually use ")
    for j in range(0, len(df2p)):
      print(df2p[df2p.columns[0]][j], " ")
      ls.append(df2p[df2p.columns[0]][j])
      count.append(j)
    print(df2p.columns[0] + " laptops \n\n")
  print("Hence the best fit specefications of a laptop for ", df1ff[df1ff.columns[0]][k], "would be \n")
  print(ls)
  print(count,"\n\n\n\n\n")
  # for h in range(1, len(count)):
  #   print(ls[h-1])
  # if(count[h]==0):
  #   print(df_Data.columns[i], "\n\n\n")
  # elif(count[h] > 0):
  #   print(" or ")
  # for l in range(0, len(ls)): 
  #      print(df2p[df2p.columns[0]][j])

# %%
pross_prio = pd.value_counts(df[''])
# Out:
# 0      2
# 1      2
# 2      3
# 3      3
# 4      3
#       ..
# 186    4
# 187    4
# 188    4
# 189    4
# 190    1
# Name: Prior_Pross, Length: 191, dtype: int64

# %%
ram_count = pd.value_counts(df_Data.RAM)
# print(processor_count.idxmax())
# print(processor_count)
# process_max = processor_count.max()
# print(process_max)
#brand_df = brand_count.to_frame(name='Brand')
ram_df = ram_count.to_frame(name='RAM')
#RAM_df = RAM_count.to_frame(name='RAM')
df1r = pd.concat([ram_df], axis=1)
df1r
df1r.reset_index(level=0, inplace=True)
df1r.rename(columns = {'index':'RAM', 'RAM':'Count'}, inplace = True)
df1r
df2r = df1r[df1r.Count == df1r.Count.max()]
print(df2r)
len(df2r)
print("The people with Data Science usually use ")
for i in range(0, len(df2r)):
  print(df2r.RAM[i], " ")

print("RAM laptops")
# Out:
#     RAM  Count
# 0  8 GB     13
# The people with Data Science usually use
# 8 GB
# RAM laptops

# %%
gc_count = pd.value_counts(df_Data.GC)
# print(processor_count.idxmax())
# print(processor_count)
# process_max = processor_count.max()
# print(process_max)
#brand_df = brand_count.to_frame(name='Brand')
gc_df = gc_count.to_frame(name='GC')
#RAM_df = RAM_count.to_frame(name='RAM')
df1gc = pd.concat([gc_df], axis=1)
df1gc
df1gc.reset_index(level=0, inplace=True)
df1gc.rename(columns = {'index':'GC', 'GC':'Count'}, inplace = True)
df1gc 
df2gc = df1gc[df1gc.Count == df1gc.Count.max()]
print(df2gc)
len(df2gc)
print("The people with Data Science usually use ")
for i in range(0, len(df2gc)):
  print(df2r.RAM[i], " ")

print("RAM laptops")

# %%
a = df_Data['Processor'].value_counts()['Intel I5']
b = df_Data['Processor'].value_counts()['Intel I7']
c = df_Data['Processor'].value_counts()['Ryzen 7']
d = df_Data['Processor'].value_counts()['Ryzen 7']

# %%
df_Data_ana = df_Data.loc[df_Data['Processor'] == 'Intel I5']
df_Data_ana

# %%
from matplotlib import pyplot as plt
from matplotlib import style
style.use('ggplot')
x = [5,8,10]
y = [12,16,6]
x2 = [6,9,11]
y2 = [6,15,7]
plt.plot(x,y,'g',label='line one', linewidth=5)
plt.plot(x2,y2,'c',label='line two',linewidth=5)
plt.title('Epic Info')
plt.ylabel('Y axis')
plt.xlabel('X axis')
plt.legend()
plt.grid(True,color='R')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/pylabtools.py:128: MatplotlibDeprecationWarning: Support for uppercase single-letter colors is deprecated since Matplotlib 3.1 and will be removed in 3.3; please use lowercase instead.
#   fig.canvas.print_figure(bytes_io, **kw)
